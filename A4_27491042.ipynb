# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
from pandas.api.types import is_numeric_dtype
from scipy import stats
sns.set()

# %% [markdown]
# # <center>Situation</center>
# - Trying to track political activity of people in the UK from The Audit of Political Engagement.
# - The Audit is being done 18 months before the general election to see public engagement and attitudes.

# %% [markdown]
# # <center>Problem</center>
# - Find out what insight we can get on why UK citizens have a negative attitude towards the government.
# - Its important because this could lead to hurting the democratic system in place.
# - The main problem is that people's attitude towards the government is a negative one.

# %% [markdown]
# #### For each graph
# ###### 	Value = 1.0	Label = Strongly agree ,  Value = 2.0	Label = Tend to agree, Value = 3.0	Label = Neither agree nor disagree
# ###### Value = 4.0	Label = Tend to disagree, Value = 5.0	Label = Strongly disagree, Value = 6.0	Label = Don't know
# ######  Value for Age = 1.0	Label = 18-24, Value for Age = 2.0	Label = 25-34, Value for Age = 3.0	Label = 35-44, Value for Age = 4.0	Label = 45-54, Value for Age = 5.0	Label = 55-59
# ###### Value for Age = 6.0	Label = 60-64, Value for Age = 7.0	Label = 65+, Value for Age = 8.0	Label = Don't know

# %%
df = pd.read_csv('SN7577.tab', sep='\t')

bin = np.arange(0.51,7.5,1)
f1, axe1 = plt.subplots()
axe1.hist(df['Q16a'],bins=bin)
axe1.set_ylim(bottom=-2)
axe1.set_title('PMQ deals with the important issues facing the country')
axe1.set_ylabel('Frequency')
b=axe1.set_xlabel('Value')

# %% [markdown]
# ###### The graph above represents if people agree that PMQ deals with the important issues facing the country.
# ###### This data shows that people tend to agree or are neutral that PMQ deals with important issues.
# ###### However the next graph shows something funny.

# %%
bin = np.arange(0.51,7.5,1)
f1, axe1 = plt.subplots()
axe1.hist(df['Q16c'],bins=bin)
axe1.set_ylim(bottom=-2)
axe1.set_title('There is too much party political point scoring instead of answering the question')
axe1.set_ylabel('Frequency')
b=axe1.set_xlabel('Value')

# %% [markdown]
# ###### This graph represents the peoples opinion "if politicians focus on scoring points rather than answering the Questions".
# ###### As you can see majority of people agree with the fact that politicians tend to avoid the question trying to attain points.
# ###### this could be a reason why people in the UK have a negative attitude towards politics.

# %%
g3 = sns.FacetGrid(df, col='Q16a') # it divides it into diffrent categories 
s=g3.map(plt.hist, 'Q16c', bins=20)

# %% [markdown]
# ###### When comparing those who agreed to  PMQ "deals with the important issues facing the country(Q16a)" also agree that "There is too much party political point scoring instead of answering the question(Q16c)"
# ###### this can indicate that the negative perception comes from not focusing on the topic but instead on attaining the points required.

# %%
bin = np.arange(0.51,7.5,1)
f1, axe1 = plt.subplots()
axe1.hist(df['Q16b'],bins=bin)
axe1.set_ylim(bottom=-2)
axe1.set_title('Proud of our Parliament')
axe1.set_ylabel('Frequency')
b=axe1.set_xlabel('Value')

# %% [markdown]
# ###### The graph above represents how proud the citizens of the UK are of PMQ.
# ###### This graph is showing that most people are neutral to not being proud of their government can be the of why there is low participation.

# %%
bin = np.arange(0.51,7.5,1)
f1, axe1 = plt.subplots()
axe1.hist(df['Q10a'],bins=bin)
axe1.set_ylim(bottom=-2)
axe1.set_title('The UK Parliament holds government to accountt')
axe1.set_ylabel('Frequency')
b=axe1.set_xlabel('Value')

# %% [markdown]
# ###### The Graph above here shows us that only 34% of people belive that The UK Parliament holds government to account

# %%
bin = np.arange(0.51,7.5,1)
f1, axe1 = plt.subplots()
axe1.hist(df['Q17g'],bins=bin)
axe1.set_ylim(bottom=-2)
axe1.set_title('Politicians don\'t understand the daily lives of people like me')
axe1.set_ylabel('Frequency')
b=axe1.set_xlabel('Value')

# %% [markdown]
# ###### The graph above represents how politicians failed to understand how the daily lives of people.
# ###### Indicating that the government is out of touch with the population/ A lack of communication.
# ###### we can see that most people belive that the government is not able to understand how people live their lives.
# ###### from the graph above we can see by adding up the two coumns that 64 percent of the population belives this.

# %%
g3 = sns.FacetGrid(df, col='Q17g') 
n=g3.map(plt.hist, 'age', bins=20)

# %% [markdown]
# ###### if we compare how politicians failed to understand how the daily lives of people and age you can see that all age groups feel as if the government is out of touch with the people.

# %%
bin = np.arange(0.51,6.5,1)
f1, axe1 = plt.subplots()
axe1.hist(df['Q8'],bins=bin)
axe1.set_ylim(bottom=-2)
axe1.set_title('Describes your opinion on the present system of governing Britain')
axe1.set_ylabel('Frequency')
b=axe1.set_xlabel('Value')

# %% [markdown]
# ###### This graph represents the opinion on the present system of governing Britain and how the people view the government as you can see from the graph
# ###### that majority of people belive that the government needs some sort of improvement. the second bar represents people who belive the goverment needs some improvement
# ###### Value = 1.0	Label = Works extremely well and could not be improved
# ###### Value = 2.0	Label = Could be improved in small ways but mainly works well
# ###### Value = 3.0	Label = Could be improved quite a lot
# ###### Value = 4.0	Label = Needs a great deal of improvement
# ###### Value = 5.0	Label = Don't know
#
# ###### From this graph we can conclude that 92 percent of the population thinks the present system of governing Britain needs some sort of improvement.

# %%
g3 = sns.FacetGrid(df, col='Q8') 
k=g3.map(plt.hist, 'age', bins=20)

# %% [markdown]
# ###### if we further break it into age groups we can see that all age groups agree on the fact that the present system of governing Britaint needs to improve.

# %%
g4 = sns.FacetGrid(df, col='Q17b')  
z=g4.map(plt.hist, 'Q17c')

# %% [markdown]
# ###### The Graph above compares public opinion on "Politicians should be expected to act according to a set of guidelines about their behaviour" with "Politicians should have to undertake regular ethics and standards training"
# ###### Here everyone agrees that politicans should be expected to behave in a manner that is ethical and proper.
# ###### people may have a negative view on the government because politicians are behaving ethically.
# ###### 75 percent of people belive Politicians should have to undertake regular ethics and standards training
# ###### 80 percent of people belive that Politicians should be expected to act according to a set of guidelines about their behaviour

# %% [markdown]
# # <center>Solution</center>
# - In order to chnage public opinion on politicians and government must figure out a way to collect information on what issues matter to the public so  the public feels as if the government cares.
# - It is clear from the last two graphs presented that in order to change public opinion politicians should go trough ethical training and behave accordingly.

# %% [markdown]
# # <center>Next Step</center>
# - Find an appropriate way to gather information about what is important to understand how the daily lives of citizens by surveys or having weekly town meetings.
# - Hire a team of programmers to create an cell phone application that lets people vote on topics they are intrested in.
# - Encorperate ethical training seminars for politicians.
# - To find a way to hold government and politicians accountable.
