# %%
import pandas as pd
import numpy as np
from scipy import stats
from pandas.api.types import is_numeric_dtype
import seaborn as sns

# %%
df =pd.read_csv('vgsales.csv')
df5=pd.read_csv('tips.csv')

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
df.describe()
#count is all non null values
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
#df.isnull().sum()
#adds all the ones
#when you do describe ou only get number values 
#end goal is to have an output will have the diffrent matrixs we want
# the rows will have the names of the variables

# %%
df.describe().T
# Out:
#                 count         mean          std      min      25%      50%  \
# Rank          16598.0  8300.605254  4791.853933     1.00  4151.25  8300.50
# Year          16327.0  2006.406443     5.828981  1980.00  2003.00  2007.00
# NA_Sales      16598.0     0.264667     0.816683     0.00     0.00     0.08
# EU_Sales      16598.0     0.146652     0.505351     0.00     0.00     0.02
# JP_Sales      16598.0     0.077782     0.309291     0.00     0.00     0.00
# Other_Sales   16598.0     0.048063     0.188588     0.00     0.00     0.01
# Global_Sales  16598.0     0.537441     1.555028     0.01     0.06     0.17
#
#                    75%       max
# Rank          12449.75  16600.00
# Year           2010.00   2020.00
# NA_Sales          0.24     41.49
# EU_Sales          0.11     29.02
# JP_Sales          0.04     10.22
# Other_Sales       0.04     10.57
# Global_Sales      0.47     82.74

# %%
#create dataFrame outside function so any can used
df2=pd.read_csv('vgsales.csv')
def quantDDA(df):
    pandas_stats_df=df.describe().T
    Q1=df.describe().loc['25%']
    Q3=df.describe().loc['75%']
    IQR=Q3-Q1
    IQR_df=pd.DataFrame(IQR)
    IQR_df.columns=['IQR']
    output_df=pd.concat([pandas_stats_df,IQR_df],axis=1)
    lower_value= Q1-(1.5*IQR)
    lower_value
    upper_value= Q3+(1.5*IQR)
    upper_value
    outliers =pd.DataFrame(((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).sum())
    outliers.columns=['Count_Outliers']
    extremes_df =pd.DataFrame(((df < (Q1 - 3.0 * IQR)) | (df > (Q3 + 3.0 * IQR))).sum())
    extremes_df.columns=['Count_Of_Extremes']
    
    list_of_columns=list(df.columns)
    stats_dict={}
    for x in list_of_columns: #how does the program know the list of columns if i did not define it ?
        if(is_numeric_dtype(df[x])):
            #stats.describe(df[x])
            skewness=stats.describe(df[x]).skewness
            variance=stats.describe(df[x]).variance
            kurtosis=stats.describe(df[x]).kurtosis
            number_of_obs=stats.describe(df[x]).nobs
            stats_dict[x]={'Nobs':number_of_obs, 'skewness':skewness, 'variance':variance, 'kurtosis':kurtosis}

#print(stats_dict)
    new_df=pd.DataFrame(df.nunique())
    new_df.columns=['Unique_Values']
    null_df=pd.DataFrame(df.isnull().sum())
    null_df.columns=['Null_Values']
    
    stats_df=pd.DataFrame(stats_dict).T
    mode_df=df.mode(axis=0,numeric_only=True).dropna().T
    mode_df.columns=['Mode']
    outputdf=pd.concat([output_df,outliers,extremes_df,stats_df,mode_df,new_df,null_df],axis=1)
    
    
  

    return outputdf

# %%
quantDDA(df5)
# Out:
#             count        mean        std   min      25%      50%       75%  \
# Unnamed: 0  244.0  122.500000  70.580923  1.00  61.7500  122.500  183.2500
# total_bill  244.0   19.785943   8.902412  3.07  13.3475   17.795   24.1275
# tip         244.0    2.998279   1.383638  1.00   2.0000    2.900    3.5625
# size        244.0    2.569672   0.951100  1.00   2.0000    2.000    3.0000
# day           NaN         NaN        NaN   NaN      NaN      NaN       NaN
# sex           NaN         NaN        NaN   NaN      NaN      NaN       NaN
# smoker        NaN         NaN        NaN   NaN      NaN      NaN       NaN
# time          NaN         NaN        NaN   NaN      NaN      NaN       NaN
#
#                max       IQR  Count_Outliers  Count_Of_Extremes   Nobs  \
# Unnamed: 0  244.00  121.5000               0                  0  244.0
# total_bill   50.81   10.7800               9                  0  244.0
# tip          10.00    1.5625               9                  2  244.0
# size          6.00    1.0000               9                  0  244.0
# day            NaN       NaN               0                  0    NaN
# sex            NaN       NaN               0                  0    NaN
# smoker         NaN       NaN               0                  0    NaN
# time           NaN       NaN               0                  0    NaN
#
#             skewness     variance  kurtosis   Mode  Unique_Values  Null_Values
# Unnamed: 0  0.000000  4981.666667 -1.200040   1.00            244            0
# total_bill  1.126235    79.252939  1.169168  13.42            229            0
# tip         1.456427     1.914455  3.549552   2.00            123            0
# size        1.438965     0.904591  1.671928   2.00              6            0
# day              NaN          NaN       NaN    NaN              4            0
# sex              NaN          NaN       NaN    NaN              2            0
# smoker           NaN          NaN       NaN    NaN              2            0
# time             NaN          NaN       NaN    NaN              2            0

# %%
df2.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
#iqr is the interquartial range this is Q3-Q1
#loc your are using beacsuse its index if i want to take a row i use loc
Q1=df2.describe().loc['25%']
Q3=df2.describe().loc['75%']
IQR=Q3-Q1
IQR

lower_value= Q1-(1.5*IQR)
lower_value

upper_value= Q3+(1.5*IQR)
upper_value

#(df2 > upper_value | df2 < lower_value).sum()
outliers =pd.DataFrame(((df2 < (Q1 - 1.5 * IQR)) | (df2 > (Q3 + 1.5 * IQR))))
# this gives me the count adds everywhere you have a T
#this shows the values that are bellow and above the upper and lower values 
#the number of records that are outliers
#print(outliers)
#print(outliers.sum())
#type(IQR)
#i have convert panda series to a data frame
# how to remove it from the data set

# %%
#df2.describe()["Rank"]
#this will make your series into a df
IQR_df=pd.DataFrame(IQR)
IQR_df.columns=['IQR']
IQR_df
# Out:
#                   IQR
# Rank          8298.50
# Year             7.00
# NA_Sales         0.24
# EU_Sales         0.11
# JP_Sales         0.04
# Other_Sales      0.04
# Global_Sales     0.41

# %%
#stats.describe(df['Name'])

# %%
stats.describe(df['Name']).nobs
# Out:
# 16598

# %%
list_of_columns=list(df.columns)

# %%
print(list_of_columns)
# Out:
# ['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']

# %%
stats_dict={}
for x in list_of_columns:
    if(is_numeric_dtype(df[x])):
        #stats.describe(df[x])
        skewness=stats.describe(df[x]).skewness
        variance=stats.describe(df[x]).variance
        kurtosis=stats.describe(df[x]).kurtosis
        number_of_obs=stats.describe(df[x]).nobs
        stats_dict[x]={'Nobs':number_of_obs, 'skewness':skewness, 'variance':variance, 'kurtosis':kurtosis}

print(stats_dict)
pd.DataFrame(stats_dict).T
# Out:
# {'Rank': {'Nobs': 16598, 'skewness': 6.649115879568427e-05, 'variance': 22961864.11421473, 'kurtosis': -1.199864912817033}, 'Year': {'Nobs': 16598, 'skewness': nan, 'variance': nan, 'kurtosis': nan}, 'NA_Sales': {'Nobs': 16598, 'skewness': 18.797928394933514, 'variance': 0.6669711703447947, 'kurtosis': 648.9343780267919}, 'EU_Sales': {'Nobs': 16598, 'skewness': 18.873829231551312, 'variance': 0.2553798669631976, 'kurtosis': 755.7997068520809}, 'JP_Sales': {'Nobs': 16598, 'skewness': 11.20544559299173, 'variance': 0.09566070499110912, 'kurtosis': 194.17512586440537}, 'Other_Sales': {'Nobs': 16598, 'skewness': 24.231732400307347, 'variance': 0.03556558571316838, 'kurtosis': 1025.038932068787}, 'Global_Sales': {'Nobs': 16598, 'skewness': 17.399072521163873, 'variance': 2.418111880402823, 'kurtosis': 603.7500707842869}}
#                  Nobs   skewness      variance     kurtosis
# Rank          16598.0   0.000066  2.296186e+07    -1.199865
# Year          16598.0        NaN           NaN          NaN
# NA_Sales      16598.0  18.797928  6.669712e-01   648.934378
# EU_Sales      16598.0  18.873829  2.553799e-01   755.799707
# JP_Sales      16598.0  11.205446  9.566070e-02   194.175126
# Other_Sales   16598.0  24.231732  3.556559e-02  1025.038932
# Global_Sales  16598.0  17.399073  2.418112e+00   603.750071

# %%
is_numeric_dtype(df["EU_Sales"])
# Out:
# True

# %%
mode_df=df.mode(axis=0,numeric_only=True).dropna().T

# %%
mode_df.columns=['Mode']

# %%
mode_df
# Out:
#                  Mode
# Rank             1.00
# Year          2009.00
# NA_Sales         0.00
# EU_Sales         0.00
# JP_Sales         0.00
# Other_Sales      0.00
# Global_Sales     0.02

# %%
pd.DataFrame(df.groupby('Platform').nunique().sum()) # what was this again? is this all the unique characteritics?
# Out:
#                   0
# Rank          16598
# Name          16593
# Platform         31
# Year            257
# Genre           293
# Publisher      1801
# NA_Sales       2208
# EU_Sales       1627
# JP_Sales       1221
# Other_Sales     811
# Global_Sales   3259

# %%
pd.DataFrame(df.isnull().sum()) # checking for null columns
# Out:
#                 0
# Rank            0
# Name            0
# Platform        0
# Year          271
# Genre           0
# Publisher      58
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0

# %%
#pair plot

# %%
sns.pairplot(df2)

def vizDDA(df):
    return sns.pairplot(df)

# %%
MissingValueCount_df=pd.DataFrame(df.isnull().sum(axis=1))
MissingValueCount_df.columns=['MissingValueCount']
MissingValueCount_df
# Out:
#        MissingValueCount
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 16593                  0
# 16594                  0
# 16595                  0
# 16596                  0
# 16597                  0
#
# [16598 rows x 1 columns]

# %%
def add_missingValueCount(df):
    MissingValueCount_df=pd.DataFrame(df.isnull().sum(axis=1))
    MissingValueCount_df.columns=['MissingValueCount']
    revised_df=pd.concat([df,MissingValueCount_df],axis=1)
    return revised_df

# %%
df3=add_missingValueCount(df2)

# %%
quantDDA(df3)
# Out:
#                      count         mean          std      min      25%  \
# Rank               16598.0  8300.605254  4791.853933     1.00  4151.25
# Year               16327.0  2006.406443     5.828981  1980.00  2003.00
# NA_Sales           16598.0     0.264667     0.816683     0.00     0.00
# EU_Sales           16598.0     0.146652     0.505351     0.00     0.00
# JP_Sales           16598.0     0.077782     0.309291     0.00     0.00
# Other_Sales        16598.0     0.048063     0.188588     0.00     0.00
# Global_Sales       16598.0     0.537441     1.555028     0.01     0.06
# MissingValueCount  16598.0     0.019822     0.148597     0.00     0.00
# Genre                  NaN          NaN          NaN      NaN      NaN
# Name                   NaN          NaN          NaN      NaN      NaN
# Platform               NaN          NaN          NaN      NaN      NaN
# Publisher              NaN          NaN          NaN      NaN      NaN
#
#                        50%       75%       max      IQR  Count_Outliers  \
# Rank               8300.50  12449.75  16600.00  8298.50             0.0
# Year               2007.00   2010.00   2020.00     7.00           305.0
# NA_Sales              0.08      0.24     41.49     0.24          1681.0
# EU_Sales              0.02      0.11     29.02     0.11          2081.0
# JP_Sales              0.00      0.04     10.22     0.04          2425.0
# Other_Sales           0.01      0.04     10.57     0.04          1665.0
# Global_Sales          0.17      0.47     82.74     0.41          1893.0
# MissingValueCount     0.00      0.00      2.00      NaN             NaN
# Genre                  NaN       NaN       NaN      NaN             0.0
# Name                   NaN       NaN       NaN      NaN             0.0
# Platform               NaN       NaN       NaN      NaN             0.0
# Publisher              NaN       NaN       NaN      NaN             0.0
#
#                    Count_Of_Extremes     Nobs   skewness      variance  \
# Rank                             0.0  16598.0   0.000066  2.296186e+07
# Year                            55.0  16598.0        NaN           NaN
# NA_Sales                       944.0  16598.0  18.797928  6.669712e-01
# EU_Sales                      1278.0  16598.0  18.873829  2.553799e-01
# JP_Sales                      1736.0  16598.0  11.205446  9.566070e-02
# Other_Sales                   1038.0  16598.0  24.231732  3.556559e-02
# Global_Sales                  1048.0  16598.0  17.399073  2.418112e+00
# MissingValueCount                NaN  16598.0   8.062999  2.208102e-02
# Genre                            0.0      NaN        NaN           NaN
# Name                             0.0      NaN        NaN           NaN
# Platform                         0.0      NaN        NaN           NaN
# Publisher                        0.0      NaN        NaN           NaN
#
#                       kurtosis     Mode
# Rank                 -1.199865     1.00
# Year                       NaN  2009.00
# NA_Sales            648.934378     0.00
# EU_Sales            755.799707     0.00
# JP_Sales            194.175126     0.00
# Other_Sales        1025.038932     0.00
# Global_Sales        603.750071     0.02
# MissingValueCount    71.312922     0.00
# Genre                      NaN      NaN
# Name                       NaN      NaN
# Platform                   NaN      NaN
# Publisher                  NaN      NaN

# %%
vizDDA(df3)

# %%
# each dot represents # of missing/null  values in a row

# %%
new_df=pd.DataFrame(df.nunique())

# %%
new_df
# Out:
#                   0
# Rank          16598
# Name          11493
# Platform         31
# Year             39
# Genre            12
# Publisher       578
# NA_Sales        409
# EU_Sales        305
# JP_Sales        244
# Other_Sales     157
# Global_Sales    623

# %%
#dhsjkdhaskdhal
